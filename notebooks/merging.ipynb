# %%
import pandas as pd
import numpy as np

# %%
best_seasons = pd.read_csv("../datasets/cleaned_best_seasons.csv")
best_seasons = best_seasons.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
best_seasons
# Out:
#              player_name team_abbreviation  age  player_height  player_weight  \
# 0             A.C. Green               DAL   34           81.0          225.0
# 1          A.J. Bramlett               CLE   23           82.0          227.0
# 2            A.J. Guyton               CHI   23           73.0          180.0
# 3            A.J. Lawson               DAL   22           78.0          179.0
# 4               AJ Green               MIL   23           77.0          190.0
# ...                  ...               ...  ...            ...            ...
# 2546     Zion Williamson               NOP   20           79.0          284.0
# 2547        Zoran Dragic               MIA   26           77.0          200.0
# 2548      Zoran Planinic               NJN   22           79.0          200.0
# 2549  Zydrunas Ilgauskas               CLE   28           87.0          260.0
# 2550      Zylan Cheatham               NOP   24           77.0          220.0
#
# ...

# %%
draft_combine = pd.read_csv('../datasets/cleaned_draft_combine.csv')
draft_combine = draft_combine.drop('Unnamed: 0', axis=1)
draft_combine
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 draft_combine = pd.read_csv('../datasets/draft_combine_data.csv')
#       2 draft_combine = draft_combine.drop('Unnamed: 0', axis=1)
#       3 draft_combine
#
# ...

# %%
merged_df = pd.merge(best_seasons, draft_combine, left_on='player_name', right_on='PLAYER')
merged_df = merged_df.drop(['team_abbreviation', 'college', 'country', 'HANDL', 'HANDW', 'PLAYER', 'YEAR', 'HGT', 'WGT'], axis=1)
merged_df
# Out:
#           player_name  age  player_height  player_weight  draft_year  \
# 0         A.J. Guyton   23           73.0          180.0      2000.0
# 1        Aaron Brooks   25           72.0          161.0      2007.0
# 2        Aaron Gordon   22           81.0          220.0      2014.0
# 3          Aaron Gray   23           84.0          270.0      2007.0
# 4      Aaron Harrison   23           78.0          210.0         NaN
# ..                ...  ...            ...            ...         ...
# 979  Zach Norvell Jr.   22           77.0          205.0      2019.0
# 980        Zeke Nnaji   21           81.0          240.0      2020.0
# 981      Zhaire Smith   20           76.0          199.0      2018.0
# 982           Zhou Qi   23           85.0          210.0      2016.0
# 983   Ziaire Williams   20           81.0          185.0      2021.0
#
#     draft_round draft_number  gp   pts  reb  ...    POS    BMI      BF  \
# ...

# %%
merged_df.columns
# Out:
# Index(['player_name', 'age', 'player_height', 'player_weight', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'usg_pct', 'ts_pct', 'ast_pct', 'season', 'POS', 'BMI', 'BF', 'WNGSPN',
#        'STNDRCH', 'STNDVERT', 'LPVERT', 'LANE', 'SHUTTLE', 'SPRINT'],
#       dtype='object')

# %%
merged_df.info
# Out:
# <bound method DataFrame.info of           player_name  age  player_height  player_weight  draft_year  \
# 0         A.J. Guyton   23           73.0          180.0      2000.0
# 1        Aaron Brooks   25           72.0          161.0      2007.0
# 2        Aaron Gordon   22           81.0          220.0      2014.0
# 3          Aaron Gray   23           84.0          270.0      2007.0
# 4      Aaron Harrison   23           78.0          210.0         NaN
# ..                ...  ...            ...            ...         ...
# 979  Zach Norvell Jr.   22           77.0          205.0      2019.0
# 980        Zeke Nnaji   21           81.0          240.0      2020.0
# 981      Zhaire Smith   20           76.0          199.0      2018.0
# 982           Zhou Qi   23           85.0          210.0      2016.0
# 983   Ziaire Williams   20           81.0          185.0      2021.0
#
#     draft_round draft_number  gp   pts  reb  ...    POS    BMI      BF  \
# ...

# %%
merged_df.dtypes
# Out:
# player_name       object
# age                int64
# player_height    float64
# player_weight    float64
# draft_year       float64
# draft_round       object
# draft_number      object
# gp                 int64
# pts              float64
# reb              float64
# ast              float64
# net_rating       float64
# usg_pct          float64
# ts_pct           float64
# ast_pct          float64
# season            object
# POS               object
# BMI              float64
# BF               float64
# WNGSPN           float64
# STNDRCH          float64
# STNDVERT         float64
# LPVERT           float64
# LANE             float64
# SHUTTLE          float64
# SPRINT           float64
# dtype: object

# %%
test = merged_df[merged_df['player_name'] == 'James Harden']
test
# Out:
#       player_name  age  player_height  player_weight  draft_year draft_round  \
# 405  James Harden   29           77.0          220.0      2009.0           1
#
#     draft_number  gp   pts  reb  ...  POS    BMI     BF  WNGSPN  STNDRCH  \
# 405            3  78  36.1  6.6  ...   SG  27.02  0.101   82.75    103.5
#
#     STNDVERT LPVERT  LANE  SHUTTLE  SPRINT
# 405     31.5   37.0  11.1      NaN    3.13
#
# [1 rows x 26 columns]

# %%
merged_df.to_csv("merged_player_data.csv", index=False)
